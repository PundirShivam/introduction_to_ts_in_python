# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## What  is a white noise?
#
# A time series may be white noise. A time series is white noise if the variables are independent and identically distributed with a mean of zero. This means that all variables have the same variance (sigma2) and each value has a zero correlation with all other values in the series. If
# the variables in the series are drawn from a Gaussian distribution, the series is called Gaussian white noise.
#
# __constant variance , zero auto-correlation and zero mean__
#
# ## Why does it matter?
#
# - Predictability : if the ts is white noise, it is random by definition and we cannot make predictions for it.
#
# - Model Diagnostics: error terms for our ts forecast should ideally be white noise
#
# ### Checks , if ts is white noise?
#
# If these conditions are full filled then yes,
# __constant variance , zero auto-correlation and zero mean__

# %%
noise = pd.Series(np.random.normal(0,1,1000))

# %%
_ = noise.plot(style='b').set(title="white noise")

# %%
noise.describe()
# mean is clsoed
# and std is close to one
# Out:
# count    1000.000000
# mean       -0.005892
# std         0.966821
# min        -3.122388
# 25%        -0.629653
# 50%         0.038135
# 75%         0.660311
# max         2.736734
# dtype: float64

# %%
noise.plot.hist(bins=40).set(title='histogram')
# Out:
# [Text(0.5, 1.0, 'histogram')]

# %%
# Lag plot

# %%
pd.plotting.autocorrelation_plot(noise)
# practically zero auto-correlation

# %% [markdown]
# # Summary
# - White noise time series is defned by a zero mean, constant variance, and zero correlation.
# - If your time series is white noise, it cannot be predicted, and if your forecast residuals are
# not white noise, you may be able to improve your model.
# - The statistics and diagnostic plots you can use on your time series to check if it is white
# noise.
