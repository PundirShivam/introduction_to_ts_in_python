# %%
import pandas as pd
import numpy as np

# %%
airline = pd.read_csv(r"./data/airline-passengers.txt",sep='\t',parse_dates=True,index_col='Month')

# %%
airline.index.name = 'Date'

# %%
airline.plot(grid=True).set(xlabel='')
airline.hist(bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000219121B44A8>]],
#       dtype=object)

# %%
# Square Root Transform
np.sqrt(airline).plot(grid=True).set(xlabel='')
np.sqrt(airline).hist(bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002191229BE80>]],
#       dtype=object)

# %%
# Log Transform
np.log(airline).plot(grid=True).set(xlabel='')
np.log(airline).hist(bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002191239EEB8>]],
#       dtype=object)

# %% [markdown]
# # Box - Cox Transform
# The square root transform and log transform belong to a class of transforms called power transforms. The Box-Cox transform2 is a congurable data transform method that supports both square root and log transform, as well as a suite of related transforms.
#
#
# scipy.stats boxcox function takes lambda as an argument.
#
# - lambda = -1.0 is a reciprocal transform.
# - lambda = -0.5 is a reciprocal square root transform.
# - lambda = 0.0 is a log transform.
# - lambda = 0.5 is a square root transform.
# - lambda = 1.0 is no transform.
#
# If lmbda argument is not passed to boxcox,
# returns the lmbda which maximises the
# log-likelihood.

# %%
from scipy.stats import boxcox

# %%
airline['Passengers'],lmbda = boxcox(airline['Passengers'])

# %%
np.log(airline).plot(grid=True).set(xlabel='')
np.log(airline).hist(bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000219148730B8>]],
#       dtype=object)
